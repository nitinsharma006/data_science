# %% [markdown]
# <a href="https://colab.research.google.com/github/nitinsharma006/data_science/blob/main/Image_Augmentation_Techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Image Augmentation Techniques
#
# 1. Image Rotation
# 2. Image Shifting
# 3. Image Flipping
# 4. Image Noising
# 5. Image Blurring

# %%
# importing libraries
import numpy as np
from skimage.io import imread, imshow
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. Image Rotation

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1SR1fP6qeJ3gTB2DVusjrKw1ALF3EC1j-)

# %%
# reading the image
image = imread('emergency_car.jpg')
print('Original Image')
#show original image
imshow(image)
# Out:
# Original Image

# %%
#import required libraries
from skimage.transform import rotate

#rotating the image by 30 degrees
rotated = rotate(image,angle=30)
#plot the rotated image
print('Rotated Image')
imshow(rotated)
# Out:
# Rotated Image

# %% [markdown]
# ### 2. Image Shifting

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1N9U2odUqKBNVgFtKaKcahXx5_ITo-cAg)

# %% [markdown]
# After the shift operation, an object present at location (x,y) in the input image is shifted to a new position (X,Y):
#
#
# **X = x + dx**
#
#
# **Y = y + dy**

# %%
#read the image
image = imread('emergency_car.jpg')

plt.imshow(image)
plt.title('Original Image')
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
#apply shift operation
from skimage.transform import AffineTransform, warp
transform = AffineTransform(translation=(40,40))
Shift = warp(image,transform)

plt.imshow(Shift)
plt.title('Normal Shift')
# Out:
# Text(0.5, 1.0, 'Normal Shift')

# %%
# filling the black portion of image
wrapShift = warp(image,transform,mode='edge')
plt.imshow(wrapShift)
plt.title('Wrap Shift')
# Out:
# Text(0.5, 1.0, 'Wrap Shift')

# %% [markdown]
# ### 3. Image Flipping

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1R-XkLah3r3o3iCo-oAjRUA_1SGE3BxCt)

# %%
#reading the image
image = imread('emergency_car.jpg')

plt.imshow(image)
plt.title('Original Image')
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
#flip image left-to-right
flipLR = np.fliplr(image)

plt.imshow(flipLR)
plt.title('Left to Right Flipped')
# Out:
# Text(0.5, 1.0, 'Left to Right Flipped')

# %%
#flip image up-to-down
flipUD = np.flipud(image)

plt.imshow(flipUD)
plt.title('Up Down Flipped')
# Out:
# Text(0.5, 1.0, 'Up Down Flipped')

# %% [markdown]
# ### 4. Image Noising

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1Uo2XPJ306dGSKCUbGE_Lw6L-Bpyn1lnc)

# %%
#read the image
image = imread('emergency_car.jpg')

plt.imshow(image)
plt.title('Original Image')
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
# importing library first
from skimage.util import random_noise
#add random noise to the image
noisyRandom = random_noise(image,var=0.2)

plt.imshow(noisyRandom)
plt.title('Random Noise')
# Out:
# Text(0.5, 1.0, 'Random Noise')

# %%
#add gaussian noise to the image
noisyGaussian = random_noise(image,mode='gaussian')

plt.imshow(noisyGaussian)
plt.title('Gaussian Noise')
# Out:
# Text(0.5, 1.0, 'Gaussian Noise')

# %% [markdown]
# ### 5. Image Blurring

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1hfLCSdm2CTYLbp7aklDXqMFbcAO1g3g-)

# %%
#read the image
image = imread('emergency_car.jpg')

plt.imshow(image)
plt.title('Original Image')
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
#import required libraries
from skimage.filters import gaussian

#blur the image
blurred = gaussian(image,sigma=2.5,multichannel=True)

plt.imshow(blurred)
plt.title('Blurred Image')
# Out:
# Text(0.5, 1.0, 'Blurred Image')
